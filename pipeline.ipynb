# %%
import os 
import sys
import json 
import cv2
import numpy as np
import mediapipe as mp
import pandas as pd

# %%
with open('data/WLASL_v0.3.json') as f:
    data = json.load(f)

# %%
# importing video data and their respecive labels
df = pd.read_csv('WLASL_v0.3.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 # importing video data and their respecive labels
# ----> 2 df = pd.read_csv('WLASL_v0.3.csv')
#
# File c:\Users\harsh\Desktop\Final Project\venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\harsh\Desktop\Final Project\venv\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\harsh\Desktop\Final Project\venv\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\harsh\Desktop\Final Project\venv\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\harsh\Desktop\Final Project\venv\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'WLASL_v0.3.csv'

# %%
# Create a dictionary to map video IDs to labels
video_to_label = {}

for entry in data:
    label = entry['gloss']  # The word or label
    for instance in entry['instances']:
        video_id = instance['video_id']
        video_to_label[video_id] = label

# Print the first few mappings to verify
for video_id, label in list(video_to_label.items())[:5]:
    print(f"Video ID: {video_id}, Label: {label}")
# Out:
# Video ID: 69241, Label: book
# Video ID: 65225, Label: book
# Video ID: 68011, Label: book
# Video ID: 68208, Label: book
# Video ID: 68012, Label: book

# %%
len(video_to_label) # 21083 videos and their respective labels according to the json file
# Out:
# 21083

# %%
# going to the example videos folder and checking if the video files are there or not 

# Path to the videos folder
videos_folder = 'example_videos'

# Verify that each video ID in the mapping has a corresponding video file
for video_id in video_to_label.keys():
    video_path = os.path.join(videos_folder, f"{video_id}.mp4")
    if not os.path.exists(video_path):
        print(f"Warning: Video file for ID {video_id} does not exist.")
    else:
        print(f"Video file for ID {video_id} exists and is correctly mapped to label {video_to_label[video_id]}.")
# Out:
# Warning: Video file for ID 69241 does not exist.
# Warning: Video file for ID 65225 does not exist.
# Warning: Video file for ID 68011 does not exist.
# Warning: Video file for ID 68208 does not exist.
# Warning: Video file for ID 68012 does not exist.
# Warning: Video file for ID 70212 does not exist.
# Warning: Video file for ID 70266 does not exist.
# Warning: Video file for ID 07085 does not exist.
# Warning: Video file for ID 07086 does not exist.
# Warning: Video file for ID 07087 does not exist.
# Warning: Video file for ID 07069 does not exist.
# Warning: Video file for ID 07088 does not exist.
# Warning: Video file for ID 07089 does not exist.
# Warning: Video file for ID 07090 does not exist.
# Warning: Video file for ID 07091 does not exist.
# Warning: Video file for ID 07092 does not exist.
# Warning: Video file for ID 07093 does not exist.
# Warning: Video file for ID 07068 does not exist.
# Warning: Video file for ID 07094 does not exist.
# Warning: Video file for ID 07095 does not exist.
# Warning: Video file for ID 07096 does not exist.
# Warning: Video file for ID 07097 does not exist.
# Warning: Video file for ID 07070 does not exist.
# Warning: Video file for ID 07098 does not exist.
# Warning: Video file for ID 07099 does not exist.
# Warning: Video file for ID 07071 does not exist.
# Warning: Video file for ID 07072 does not exist.
# Warning: Video file for ID 07073 does not exist.
# Warning: Video file for ID 67424 does not exist.
# Warning: Video file for ID 07074 does not exist.
# Warning: Video file for ID 07075 does not exist.
# Warning: Video file for ID 07076 does not exist.
# Warning: Video file for ID 07077 does not exist.
# Warning: Video file for ID 07078 does not exist.
# Warning: Video file for ID 07079 does not exist.
# Warning: Video file for ID 07080 does not exist.
# Warning: Video file for ID 07081 does not exist.
# Warning: Video file for ID 07082 does not exist.
# Warning: Video file for ID 07083 does not exist.
# Warning: Video file for ID 07084 does not exist.
# Warning: Video file for ID 69302 does not exist.
# Warning: Video file for ID 65539 does not exist.
# Warning: Video file for ID 70173 does not exist.
# Warning: Video file for ID 68538 does not exist.
# Warning: Video file for ID 68042 does not exist.
# Warning: Video file for ID 68660 does not exist.
# Warning: Video file for ID 68041 does not exist.
# Warning: Video file for ID 17725 does not exist.
# Warning: Video file for ID 17726 does not exist.
# Warning: Video file for ID 17727 does not exist.
# Warning: Video file for ID 17728 does not exist.
# Warning: Video file for ID 17710 does not exist.
# Warning: Video file for ID 17729 does not exist.
# Warning: Video file for ID 17730 does not exist.
# Warning: Video file for ID 17731 does not exist.
# Warning: Video file for ID 17732 does not exist.
# Warning: Video file for ID 17733 does not exist.
# Warning: Video file for ID 65540 does not exist.
# Warning: Video file for ID 17734 does not exist.
# Warning: Video file for ID 17711 does not exist.
# Warning: Video file for ID 17712 does not exist.
# Warning: Video file for ID 17713 does not exist.
# Warning: Video file for ID 17714 does not exist.
# Warning: Video file for ID 17715 does not exist.
# Warning: Video file for ID 17716 does not exist.
# Warning: Video file for ID 17717 does not exist.
# Warning: Video file for ID 17718 does not exist.
# Warning: Video file for ID 17709 does not exist.
# Warning: Video file for ID 67594 does not exist.
# Warning: Video file for ID 17719 does not exist.
# Warning: Video file for ID 17720 does not exist.
# Warning: Video file for ID 17721 does not exist.
# Warning: Video file for ID 17722 does not exist.
# Warning: Video file for ID 17723 does not exist.
# Warning: Video file for ID 17724 does not exist.
# Warning: Video file for ID 12306 does not exist.
# Warning: Video file for ID 68028 does not exist.
# Warning: Video file for ID 69054 does not exist.
# Warning: Video file for ID 12328 does not exist.
# Warning: Video file for ID 12329 does not exist.
# Warning: Video file for ID 12330 does not exist.
# Warning: Video file for ID 12312 does not exist.
# Warning: Video file for ID 12331 does not exist.
# Warning: Video file for ID 12332 does not exist.
# Warning: Video file for ID 12333 does not exist.
# Warning: Video file for ID 12335 does not exist.
# Warning: Video file for ID 12336 does not exist.
# Warning: Video file for ID 12311 does not exist.
# Warning: Video file for ID 12337 does not exist.
# Warning: Video file for ID 12338 does not exist.
# Warning: Video file for ID 12313 does not exist.
# Warning: Video file for ID 12314 does not exist.
# Warning: Video file for ID 12315 does not exist.
# Warning: Video file for ID 12316 does not exist.
# Warning: Video file for ID 12317 does not exist.
# Warning: Video file for ID 12318 does not exist.
# Warning: Video file for ID 12319 does not exist.
# Warning: Video file for ID 12320 does not exist.
# Warning: Video file for ID 67519 does not exist.
# Warning: Video file for ID 12321 does not exist.
# Warning: Video file for ID 12322 does not exist.
# Warning: Video file for ID 12323 does not exist.
# Warning: Video file for ID 12324 does not exist.
# Warning: Video file for ID 12326 does not exist.
# Warning: Video file for ID 12327 does not exist.
# Warning: Video file for ID 05724 does not exist.
# Warning: Video file for ID 70348 does not exist.
# Warning: Video file for ID 68007 does not exist.
# Warning: Video file for ID 05744 does not exist.
# Warning: Video file for ID 05746 does not exist.
# Warning: Video file for ID 05728 does not exist.
# Warning: Video file for ID 05747 does not exist.
# Warning: Video file for ID 05748 does not exist.
# Warning: Video file for ID 05749 does not exist.
# Warning: Video file for ID 05750 does not exist.
# Warning: Video file for ID 05729 does not exist.
# Warning: Video file for ID 05730 does not exist.
# Warning: Video file for ID 65167 does not exist.
# Warning: Video file for ID 05731 does not exist.
# Warning: Video file for ID 05732 does not exist.
# Warning: Video file for ID 05733 does not exist.
# Warning: Video file for ID 05734 does not exist.
# Warning: Video file for ID 05735 does not exist.
# Warning: Video file for ID 05736 does not exist.
# Warning: Video file for ID 05727 does not exist.
# Warning: Video file for ID 05737 does not exist.
# Warning: Video file for ID 05739 does not exist.
# Warning: Video file for ID 05740 does not exist.
# Warning: Video file for ID 05741 does not exist.
# Warning: Video file for ID 05742 does not exist.
# Warning: Video file for ID 05743 does not exist.
# Warning: Video file for ID 09847 does not exist.
# Warning: Video file for ID 70230 does not exist.
# Warning: Video file for ID 68580 does not exist.
# Warning: Video file for ID 70263 does not exist.
# Warning: Video file for ID 68019 does not exist.
# Warning: Video file for ID 09865 does not exist.
# Warning: Video file for ID 09866 does not exist.
# Warning: Video file for ID 09848 does not exist.
# Warning: Video file for ID 09867 does not exist.
# Warning: Video file for ID 09869 does not exist.
# Warning: Video file for ID 09849 does not exist.
# Warning: Video file for ID 09850 does not exist.
# Warning: Video file for ID 09851 does not exist.
# Warning: Video file for ID 65328 does not exist.
# Warning: Video file for ID 09853 does not exist.
# Warning: Video file for ID 09854 does not exist.
# Warning: Video file for ID 09855 does not exist.
# Warning: Video file for ID 09856 does not exist.
# Warning: Video file for ID 67483 does not exist.
# Warning: Video file for ID 09857 does not exist.
# Warning: Video file for ID 09858 does not exist.
# Warning: Video file for ID 09859 does not exist.
# Warning: Video file for ID 09860 does not exist.
# Warning: Video file for ID 09861 does not exist.
# Warning: Video file for ID 09862 does not exist.
# Warning: Video file for ID 09863 does not exist.
# Warning: Video file for ID 24857 does not exist.
# Warning: Video file for ID 69345 does not exist.
# Warning: Video file for ID 68292 does not exist.
# Warning: Video file for ID 24955 does not exist.
# Warning: Video file for ID 24956 does not exist.
# Warning: Video file for ID 24941 does not exist.
# Warning: Video file for ID 24960 does not exist.
# Warning: Video file for ID 24961 does not exist.
# Warning: Video file for ID 24962 does not exist.
# Warning: Video file for ID 24965 does not exist.
# Warning: Video file for ID 24969 does not exist.
# Warning: Video file for ID 24970 does not exist.
# Warning: Video file for ID 24971 does not exist.
# Warning: Video file for ID 24972 does not exist.
# Warning: Video file for ID 65824 does not exist.
# Warning: Video file for ID 24973 does not exist.
# Warning: Video file for ID 24943 does not exist.
# Warning: Video file for ID 24946 does not exist.
# Warning: Video file for ID 24947 does not exist.
# Warning: Video file for ID 24948 does not exist.
# Warning: Video file for ID 24940 does not exist.
# Warning: Video file for ID 67715 does not exist.
# Warning: Video file for ID 24950 does not exist.
# Warning: Video file for ID 24951 does not exist.
# Warning: Video file for ID 24952 does not exist.
# Warning: Video file for ID 24954 does not exist.
# Warning: Video file for ID 11305 does not exist.
# Warning: Video file for ID 68870 does not exist.
# Warning: Video file for ID 68024 does not exist.
# Warning: Video file for ID 11327 does not exist.
# Warning: Video file for ID 11328 does not exist.
# Warning: Video file for ID 11310 does not exist.
# Warning: Video file for ID 11329 does not exist.
# Warning: Video file for ID 11330 does not exist.
# Warning: Video file for ID 11311 does not exist.
# Warning: Video file for ID 11312 does not exist.
# Warning: Video file for ID 11313 does not exist.
# Warning: Video file for ID 11314 does not exist.
# Warning: Video file for ID 11315 does not exist.
# Warning: Video file for ID 11309 does not exist.
# Warning: Video file for ID 11316 does not exist.
# Warning: Video file for ID 11317 does not exist.
# Warning: Video file for ID 11318 does not exist.
# Warning: Video file for ID 11319 does not exist.
# Warning: Video file for ID 11320 does not exist.
# Warning: Video file for ID 11321 does not exist.
# Warning: Video file for ID 11322 does not exist.
# Warning: Video file for ID 11323 does not exist.
# Warning: Video file for ID 11324 does not exist.
# Warning: Video file for ID 11325 does not exist.
# Warning: Video file for ID 11326 does not exist.
# Warning: Video file for ID 63219 does not exist.
# Warning: Video file for ID 69534 does not exist.
# Warning: Video file for ID 68890 does not exist.
# Warning: Video file for ID 68183 does not exist.
# Warning: Video file for ID 63239 does not exist.
# Warning: Video file for ID 63240 does not exist.
# Warning: Video file for ID 63241 does not exist.
# Warning: Video file for ID 63242 does not exist.
# Warning: Video file for ID 63226 does not exist.
# Warning: Video file for ID 63227 does not exist.
# Warning: Video file for ID 63228 does not exist.
# Warning: Video file for ID 63229 does not exist.
# Warning: Video file for ID 63230 does not exist.
# Warning: Video file for ID 63231 does not exist.
# Warning: Video file for ID 66778 does not exist.
# Warning: Video file for ID 63232 does not exist.
# Warning: Video file for ID 63233 does not exist.
# Warning: Video file for ID 63234 does not exist.
# Warning: Video file for ID 66779 does not exist.
# Warning: Video file for ID 66780 does not exist.
# Warning: Video file for ID 63225 does not exist.
# Warning: Video file for ID 67066 does not exist.
# Warning: Video file for ID 63236 does not exist.
# Warning: Video file for ID 63237 does not exist.
# Warning: Video file for ID 63238 does not exist.
# Warning: Video file for ID 08909 does not exist.
# Warning: Video file for ID 68018 does not exist.
# Warning: Video file for ID 70326 does not exist.
# Warning: Video file for ID 68790 does not exist.
# Warning: Video file for ID 08928 does not exist.
# Warning: Video file for ID 08929 does not exist.
# Warning: Video file for ID 08916 does not exist.
# Warning: Video file for ID 08917 does not exist.
# Warning: Video file for ID 08918 does not exist.
# Warning: Video file for ID 08919 does not exist.
# Warning: Video file for ID 08920 does not exist.
# Warning: Video file for ID 08921 does not exist.
# Warning: Video file for ID 08922 does not exist.
# Warning: Video file for ID 08923 does not exist.
# Warning: Video file for ID 65298 does not exist.
# Warning: Video file for ID 08924 does not exist.
# Warning: Video file for ID 65299 does not exist.
# Warning: Video file for ID 65300 does not exist.
# Warning: Video file for ID 08915 does not exist.
# Warning: Video file for ID 67468 does not exist.
# Warning: Video file for ID 67470 does not exist.
# Warning: Video file for ID 08925 does not exist.
# Warning: Video file for ID 08926 does not exist.
# Warning: Video file for ID 08927 does not exist.
# Warning: Video file for ID 65415 does not exist.
# Warning: Video file for ID 70332 does not exist.
# Warning: Video file for ID 68592 does not exist.
# Warning: Video file for ID 13647 does not exist.
# Warning: Video file for ID 13648 does not exist.
# Warning: Video file for ID 13631 does not exist.
# Warning: Video file for ID 13632 does not exist.
# Warning: Video file for ID 13633 does not exist.
# Warning: Video file for ID 13634 does not exist.
# Warning: Video file for ID 13635 does not exist.
# Warning: Video file for ID 13636 does not exist.
# Warning: Video file for ID 13637 does not exist.
# Warning: Video file for ID 13638 does not exist.
# Warning: Video file for ID 13630 does not exist.
# Warning: Video file for ID 13639 does not exist.
# Warning: Video file for ID 67535 does not exist.
# Warning: Video file for ID 13640 does not exist.
# Warning: Video file for ID 13641 does not exist.
# Warning: Video file for ID 13642 does not exist.
# Warning: Video file for ID 13643 does not exist.
# Warning: Video file for ID 13644 does not exist.
# Warning: Video file for ID 13645 does not exist.
# Warning: Video file for ID 13646 does not exist.
# Warning: Video file for ID 14855 does not exist.
# Warning: Video file for ID 70015 does not exist.
# Warning: Video file for ID 68586 does not exist.
# Warning: Video file for ID 68033 does not exist.
# Warning: Video file for ID 14899 does not exist.
# Warning: Video file for ID 14900 does not exist.
# Warning: Video file for ID 14882 does not exist.
# Warning: Video file for ID 14901 does not exist.
# Warning: Video file for ID 14903 does not exist.
# Warning: Video file for ID 14883 does not exist.
# Warning: Video file for ID 14884 does not exist.
# Warning: Video file for ID 14885 does not exist.
# Warning: Video file for ID 14886 does not exist.
# Warning: Video file for ID 65445 does not exist.
# Warning: Video file for ID 14887 does not exist.
# Warning: Video file for ID 14888 does not exist.
# Warning: Video file for ID 14889 does not exist.
# Warning: Video file for ID 14891 does not exist.
# Warning: Video file for ID 14893 does not exist.
# Warning: Video file for ID 14894 does not exist.
# Warning: Video file for ID 14895 does not exist.
# Warning: Video file for ID 14896 does not exist.
# Warning: Video file for ID 14898 does not exist.
# Warning: Video file for ID 65717 does not exist.
# Warning: Video file for ID 70234 does not exist.
# Warning: Video file for ID 68048 does not exist.
# Warning: Video file for ID 21885 does not exist.
# Warning: Video file for ID 21886 does not exist.
# Warning: Video file for ID 21887 does not exist.
# Warning: Video file for ID 21888 does not exist.
# Warning: Video file for ID 21870 does not exist.
# Warning: Video file for ID 21889 does not exist.
# Warning: Video file for ID 21890 does not exist.
# Warning: Video file for ID 21891 does not exist.
# Warning: Video file for ID 21871 does not exist.
# Warning: Video file for ID 21872 does not exist.
# Warning: Video file for ID 21869 does not exist.
# Warning: Video file for ID 21874 does not exist.
# Warning: Video file for ID 21875 does not exist.
# Warning: Video file for ID 21876 does not exist.
# Warning: Video file for ID 21878 does not exist.
# Warning: Video file for ID 67660 does not exist.
# Warning: Video file for ID 67659 does not exist.
# Warning: Video file for ID 21883 does not exist.
# Warning: Video file for ID 21884 does not exist.
# Warning: Video file for ID 27194 does not exist.
# Warning: Video file for ID 69364 does not exist.
# Warning: Video file for ID 27219 does not exist.
# Warning: Video file for ID 27220 does not exist.
# Warning: Video file for ID 27221 does not exist.
# Warning: Video file for ID 27206 does not exist.
# Warning: Video file for ID 27207 does not exist.
# Warning: Video file for ID 27208 does not exist.
# Warning: Video file for ID 27209 does not exist.
# Warning: Video file for ID 27210 does not exist.
# Warning: Video file for ID 27211 does not exist.
# Warning: Video file for ID 27212 does not exist.
# Warning: Video file for ID 65890 does not exist.
# Warning: Video file for ID 27213 does not exist.
# Warning: Video file for ID 27214 does not exist.
# Warning: Video file for ID 65891 does not exist.
# Warning: Video file for ID 65889 does not exist.
# Warning: Video file for ID 67757 does not exist.
# Warning: Video file for ID 27215 does not exist.
# Warning: Video file for ID 27216 does not exist.
# Warning: Video file for ID 27217 does not exist.
# Warning: Video file for ID 27218 does not exist.
# Warning: Video file for ID 38482 does not exist.
# Warning: Video file for ID 69411 does not exist.
# Warning: Video file for ID 68110 does not exist.
# Warning: Video file for ID 68406 does not exist.
# Warning: Video file for ID 38539 does not exist.
# Warning: Video file for ID 38540 does not exist.
# Warning: Video file for ID 38541 does not exist.
# Warning: Video file for ID 38542 does not exist.
# Warning: Video file for ID 38525 does not exist.
# Warning: Video file for ID 38544 does not exist.
# Warning: Video file for ID 38527 does not exist.
# Warning: Video file for ID 38529 does not exist.
# Warning: Video file for ID 38530 does not exist.
# Warning: Video file for ID 38531 does not exist.
# Warning: Video file for ID 38532 does not exist.
# Warning: Video file for ID 38533 does not exist.
# Warning: Video file for ID 66183 does not exist.
# Warning: Video file for ID 38524 does not exist.
# Warning: Video file for ID 67934 does not exist.
# Warning: Video file for ID 38534 does not exist.
# Warning: Video file for ID 38536 does not exist.
# Warning: Video file for ID 38538 does not exist.
# Warning: Video file for ID 57919 does not exist.
# Warning: Video file for ID 57948 does not exist.
# Warning: Video file for ID 57949 does not exist.
# Warning: Video file for ID 57950 does not exist.
# Warning: Video file for ID 57952 does not exist.
# Warning: Video file for ID 57934 does not exist.
# Warning: Video file for ID 57953 does not exist.
# Warning: Video file for ID 57935 does not exist.
# Warning: Video file for ID 57936 does not exist.
# Warning: Video file for ID 57937 does not exist.
# Warning: Video file for ID 66606 does not exist.
# Warning: Video file for ID 57939 does not exist.
# Warning: Video file for ID 57940 does not exist.
# Warning: Video file for ID 57941 does not exist.
# Warning: Video file for ID 57942 does not exist.
# Warning: Video file for ID 66607 does not exist.
# Warning: Video file for ID 57933 does not exist.
# Warning: Video file for ID 67299 does not exist.
# Warning: Video file for ID 57943 does not exist.
# Warning: Video file for ID 57944 does not exist.
# Warning: Video file for ID 57945 does not exist.
# Warning: Video file for ID 57947 does not exist.
# Warning: Video file for ID 62152 does not exist.
# Warning: Video file for ID 68852 does not exist.
# Warning: Video file for ID 68918 does not exist.
# Warning: Video file for ID 68177 does not exist.
# Warning: Video file for ID 62173 does not exist.
# Warning: Video file for ID 62174 does not exist.
# Warning: Video file for ID 62175 does not exist.
# Warning: Video file for ID 62159 does not exist.
# Warning: Video file for ID 62160 does not exist.
# Warning: Video file for ID 62163 does not exist.
# Warning: Video file for ID 62164 does not exist.
# Warning: Video file for ID 62165 does not exist.
# Warning: Video file for ID 66743 does not exist.
# Warning: Video file for ID 62166 does not exist.
# Warning: Video file for ID 66742 does not exist.
# Warning: Video file for ID 62158 does not exist.
# Warning: Video file for ID 67036 does not exist.
# Warning: Video file for ID 62168 does not exist.
# Warning: Video file for ID 62169 does not exist.
# Warning: Video file for ID 62170 does not exist.
# Warning: Video file for ID 62171 does not exist.
# Warning: Video file for ID 62172 does not exist.
# Warning: Video file for ID 64201 does not exist.
# Warning: Video file for ID 64211 does not exist.
# Warning: Video file for ID 68416 does not exist.
# Warning: Video file for ID 68190 does not exist.
# Warning: Video file for ID 70306 does not exist.
# Warning: Video file for ID 68992 does not exist.
# Warning: Video file for ID 64223 does not exist.
# Warning: Video file for ID 64224 does not exist.
# Warning: Video file for ID 64210 does not exist.
# Warning: Video file for ID 64212 does not exist.
# Warning: Video file for ID 66818 does not exist.
# Warning: Video file for ID 64213 does not exist.
# Warning: Video file for ID 66816 does not exist.
# Warning: Video file for ID 64209 does not exist.
# Warning: Video file for ID 64215 does not exist.
# Warning: Video file for ID 64216 does not exist.
# Warning: Video file for ID 67012 does not exist.
# Warning: Video file for ID 64217 does not exist.
# Warning: Video file for ID 64219 does not exist.
# Warning: Video file for ID 64218 does not exist.
# Warning: Video file for ID 64221 does not exist.
# Warning: Video file for ID 64222 does not exist.
# Warning: Video file for ID 64275 does not exist.
# Warning: Video file for ID 69546 does not exist.
# Warning: Video file for ID 64287 does not exist.
# Warning: Video file for ID 68192 does not exist.
# Warning: Video file for ID 64290 does not exist.
# Warning: Video file for ID 64284 does not exist.
# Warning: Video file for ID 64291 does not exist.
# Warning: Video file for ID 64292 does not exist.
# Warning: Video file for ID 64293 does not exist.
# Warning: Video file for ID 64294 does not exist.
# Warning: Video file for ID 64295 does not exist.
# Warning: Video file for ID 64296 does not exist.
# Warning: Video file for ID 66820 does not exist.
# Warning: Video file for ID 64297 does not exist.
# Warning: Video file for ID 64280 does not exist.
# Warning: Video file for ID 64298 does not exist.
# Warning: Video file for ID 64299 does not exist.
# Warning: Video file for ID 64300 does not exist.
# Warning: Video file for ID 64281 does not exist.
# Warning: Video file for ID 64288 does not exist.
# Warning: Video file for ID 64289 does not exist.
# Warning: Video file for ID 64283 does not exist.
# Warning: Video file for ID 01912 does not exist.
# Warning: Video file for ID 69206 does not exist.
# Warning: Video file for ID 68001 does not exist.
# Warning: Video file for ID 68720 does not exist.
# Warning: Video file for ID 02002 does not exist.
# Warning: Video file for ID 02003 does not exist.
# Warning: Video file for ID 01987 does not exist.
# Warning: Video file for ID 01988 does not exist.
# Warning: Video file for ID 01989 does not exist.
# Warning: Video file for ID 01990 does not exist.
# Warning: Video file for ID 01991 does not exist.
# Warning: Video file for ID 01992 does not exist.
# Warning: Video file for ID 65043 does not exist.
# Warning: Video file for ID 01995 does not exist.
# Warning: Video file for ID 01986 does not exist.
# Warning: Video file for ID 67356 does not exist.
# Warning: Video file for ID 01996 does not exist.
# Warning: Video file for ID 01997 does not exist.
# Warning: Video file for ID 01998 does not exist.
# Warning: Video file for ID 01999 does not exist.
# Warning: Video file for ID 02000 does not exist.
# Warning: Video file for ID 06455 does not exist.
# Warning: Video file for ID 69236 does not exist.
# Warning: Video file for ID 68230 does not exist.
# Warning: Video file for ID 70244 does not exist.
# Warning: Video file for ID 06472 does not exist.
# Warning: Video file for ID 06473 does not exist.
# Warning: Video file for ID 06474 does not exist.
# Warning: Video file for ID 06475 does not exist.
# Warning: Video file for ID 06476 does not exist.
# Warning: Video file for ID 06477 does not exist.
# Warning: Video file for ID 06478 does not exist.
# Warning: Video file for ID 06480 does not exist.
# Warning: Video file for ID 65200 does not exist.
# Warning: Video file for ID 06471 does not exist.
# Warning: Video file for ID 67414 does not exist.
# Warning: Video file for ID 06481 does not exist.
# Warning: Video file for ID 06482 does not exist.
# Warning: Video file for ID 06483 does not exist.
# Warning: Video file for ID 06484 does not exist.
# Warning: Video file for ID 06485 does not exist.
# Warning: Video file for ID 06486 does not exist.
# Warning: Video file for ID 69281 does not exist.
# Warning: Video file for ID 65403 does not exist.
# Warning: Video file for ID 70271 does not exist.
# Warning: Video file for ID 13213 does not exist.
# Warning: Video file for ID 13214 does not exist.
# Warning: Video file for ID 13197 does not exist.
# Warning: Video file for ID 13216 does not exist.
# Warning: Video file for ID 13217 does not exist.
# Warning: Video file for ID 13198 does not exist.
# Warning: Video file for ID 13199 does not exist.
# Warning: Video file for ID 13200 does not exist.
# Warning: Video file for ID 13201 does not exist.
# Warning: Video file for ID 65402 does not exist.
# Warning: Video file for ID 13202 does not exist.
# Warning: Video file for ID 13203 does not exist.
# Warning: Video file for ID 13205 does not exist.
# Warning: Video file for ID 13196 does not exist.
# Warning: Video file for ID 13206 does not exist.
# Warning: Video file for ID 13207 does not exist.
# Warning: Video file for ID 13208 does not exist.
# Warning: Video file for ID 13209 does not exist.
# Warning: Video file for ID 21933 does not exist.
# Warning: Video file for ID 70361 does not exist.
# Warning: Video file for ID 68050 does not exist.
# Warning: Video file for ID 68674 does not exist.
# Warning: Video file for ID 68688 does not exist.
# Warning: Video file for ID 21942 does not exist.
# Warning: Video file for ID 21943 does not exist.
# Warning: Video file for ID 21944 does not exist.
# Warning: Video file for ID 21945 does not exist.
# Warning: Video file for ID 21946 does not exist.
# Warning: Video file for ID 21949 does not exist.
# Warning: Video file for ID 21950 does not exist.
# Warning: Video file for ID 65721 does not exist.
# Warning: Video file for ID 21941 does not exist.
# Warning: Video file for ID 67663 does not exist.
# Warning: Video file for ID 21951 does not exist.
# Warning: Video file for ID 21952 does not exist.
# Warning: Video file for ID 21953 does not exist.
# Warning: Video file for ID 21954 does not exist.
# Warning: Video file for ID 21955 does not exist.
# Warning: Video file for ID 21956 does not exist.
# Warning: Video file for ID 28074 does not exist.
# Warning: Video file for ID 69368 does not exist.
# Warning: Video file for ID 70270 does not exist.
# Warning: Video file for ID 28125 does not exist.
# Warning: Video file for ID 28108 does not exist.
# Warning: Video file for ID 28109 does not exist.
# Warning: Video file for ID 28110 does not exist.
# Warning: Video file for ID 28111 does not exist.
# Warning: Video file for ID 28112 does not exist.
# Warning: Video file for ID 28113 does not exist.
# Warning: Video file for ID 28114 does not exist.
# Warning: Video file for ID 28115 does not exist.
# Warning: Video file for ID 28116 does not exist.
# Warning: Video file for ID 28107 does not exist.
# Warning: Video file for ID 28118 does not exist.
# Warning: Video file for ID 28119 does not exist.
# Warning: Video file for ID 28120 does not exist.
# Warning: Video file for ID 28121 does not exist.
# Warning: Video file for ID 28122 does not exist.
# Warning: Video file for ID 28123 does not exist.
# Warning: Video file for ID 28124 does not exist.
# Warning: Video file for ID 69389 does not exist.
# Warning: Video file for ID 33266 does not exist.
# Warning: Video file for ID 68093 does not exist.
# Warning: Video file for ID 70299 does not exist.
# Warning: Video file for ID 33285 does not exist.
# Warning: Video file for ID 33267 does not exist.
# Warning: Video file for ID 33286 does not exist.
# Warning: Video file for ID 33268 does not exist.
# Warning: Video file for ID 33269 does not exist.
# Warning: Video file for ID 33270 does not exist.
# Warning: Video file for ID 33271 does not exist.
# Warning: Video file for ID 33273 does not exist.
# Warning: Video file for ID 33274 does not exist.
# Warning: Video file for ID 33277 does not exist.
# Warning: Video file for ID 33278 does not exist.
# Warning: Video file for ID 33279 does not exist.
# Warning: Video file for ID 33280 does not exist.
# Warning: Video file for ID 33281 does not exist.
# Warning: Video file for ID 33282 does not exist.
# Warning: Video file for ID 33283 does not exist.
# Warning: Video file for ID 33284 does not exist.
# Warning: Video file for ID 34822 does not exist.
# Warning: Video file for ID 69396 does not exist.
# Warning: Video file for ID 70308 does not exist.
# Warning: Video file for ID 34823 does not exist.
# Warning: Video file for ID 34824 does not exist.
# Warning: Video file for ID 34825 does not exist.
# Warning: Video file for ID 34826 does not exist.
# Warning: Video file for ID 34827 does not exist.
# Warning: Video file for ID 34828 does not exist.
# Warning: Video file for ID 34829 does not exist.
# Warning: Video file for ID 34830 does not exist.
# Warning: Video file for ID 34831 does not exist.
# Warning: Video file for ID 67873 does not exist.
# Warning: Video file for ID 34832 does not exist.
# Warning: Video file for ID 34833 does not exist.
# Warning: Video file for ID 34834 does not exist.
# Warning: Video file for ID 34835 does not exist.
# Warning: Video file for ID 34836 does not exist.
# Warning: Video file for ID 34837 does not exist.
# Warning: Video file for ID 34838 does not exist.
# Warning: Video file for ID 34839 does not exist.
# Warning: Video file for ID 36927 does not exist.
# Warning: Video file for ID 69402 does not exist.
# Warning: Video file for ID 36945 does not exist.
# Warning: Video file for ID 36946 does not exist.
# Warning: Video file for ID 36930 does not exist.
# Warning: Video file for ID 36931 does not exist.
# Warning: Video file for ID 36932 does not exist.
# Warning: Video file for ID 36933 does not exist.
# Warning: Video file for ID 36934 does not exist.
# Warning: Video file for ID 36936 does not exist.
# Warning: Video file for ID 36937 does not exist.
# Warning: Video file for ID 36938 does not exist.
# Warning: Video file for ID 66147 does not exist.
# Warning: Video file for ID 66146 does not exist.
# Warning: Video file for ID 36929 does not exist.
# Warning: Video file for ID 67908 does not exist.
# Warning: Video file for ID 36939 does not exist.
# Warning: Video file for ID 36940 does not exist.
# Warning: Video file for ID 36941 does not exist.
# Warning: Video file for ID 36942 does not exist.
# Warning: Video file for ID 36944 does not exist.
# Warning: Video file for ID 38982 does not exist.
# Warning: Video file for ID 69413 does not exist.
# Warning: Video file for ID 38994 does not exist.
# Warning: Video file for ID 70345 does not exist.
# Warning: Video file for ID 68694 does not exist.
# Warning: Video file for ID 68770 does not exist.
# Warning: Video file for ID 68114 does not exist.
# Warning: Video file for ID 38999 does not exist.
# Warning: Video file for ID 39000 does not exist.
# Warning: Video file for ID 39001 does not exist.
# Warning: Video file for ID 39002 does not exist.
# Warning: Video file for ID 39003 does not exist.
# Warning: Video file for ID 38990 does not exist.
# Warning: Video file for ID 67937 does not exist.
# Warning: Video file for ID 39004 does not exist.
# Warning: Video file for ID 39005 does not exist.
# Warning: Video file for ID 39006 does not exist.
# Warning: Video file for ID 38991 does not exist.
# Warning: Video file for ID 38995 does not exist.
# Warning: Video file for ID 38996 does not exist.
# Warning: Video file for ID 38997 does not exist.
# Warning: Video file for ID 40114 does not exist.
# Warning: Video file for ID 69422 does not exist.
# Warning: Video file for ID 70310 does not exist.
# Warning: Video file for ID 70249 does not exist.
# Warning: Video file for ID 68122 does not exist.
# Warning: Video file for ID 40115 does not exist.
# Warning: Video file for ID 40116 does not exist.
# Warning: Video file for ID 40117 does not exist.
# Warning: Video file for ID 40118 does not exist.
# Warning: Video file for ID 40119 does not exist.
# Warning: Video file for ID 40120 does not exist.
# Warning: Video file for ID 40121 does not exist.
# Warning: Video file for ID 40122 does not exist.
# Warning: Video file for ID 40123 does not exist.
# Warning: Video file for ID 66246 does not exist.
# Warning: Video file for ID 67949 does not exist.
# Warning: Video file for ID 40124 does not exist.
# Warning: Video file for ID 40126 does not exist.
# Warning: Video file for ID 40128 does not exist.
# Warning: Video file for ID 40129 does not exist.
# Warning: Video file for ID 40130 does not exist.
# Warning: Video file for ID 56552 does not exist.
# Warning: Video file for ID 70323 does not exist.
# Warning: Video file for ID 68972 does not exist.
# Warning: Video file for ID 56573 does not exist.
# Warning: Video file for ID 56574 does not exist.
# Warning: Video file for ID 56557 does not exist.
# Warning: Video file for ID 56576 does not exist.
# Warning: Video file for ID 56577 does not exist.
# Warning: Video file for ID 56578 does not exist.
# Warning: Video file for ID 56579 does not exist.
# Warning: Video file for ID 56558 does not exist.
# Warning: Video file for ID 56556 does not exist.
# Warning: Video file for ID 56560 does not exist.
# Warning: Video file for ID 56563 does not exist.
# Warning: Video file for ID 56564 does not exist.
# Warning: Video file for ID 67275 does not exist.
# Warning: Video file for ID 56566 does not exist.
# Warning: Video file for ID 56567 does not exist.
# Warning: Video file for ID 56568 does not exist.
# Warning: Video file for ID 56569 does not exist.
# Warning: Video file for ID 56571 does not exist.
# Warning: Video file for ID 69092 does not exist.
# Warning: Video file for ID 57645 does not exist.
# Warning: Video file for ID 57646 does not exist.
# Warning: Video file for ID 57628 does not exist.
# Warning: Video file for ID 57647 does not exist.
# Warning: Video file for ID 57629 does not exist.
# Warning: Video file for ID 57630 does not exist.
# Warning: Video file for ID 57631 does not exist.
# Warning: Video file for ID 57632 does not exist.
# Warning: Video file for ID 57633 does not exist.
# Warning: Video file for ID 57634 does not exist.
# Warning: Video file for ID 67292 does not exist.
# Warning: Video file for ID 57635 does not exist.
# Warning: Video file for ID 57636 does not exist.
# Warning: Video file for ID 57637 does not exist.
# Warning: Video file for ID 57638 does not exist.
# Warning: Video file for ID 57639 does not exist.
# Warning: Video file for ID 57640 does not exist.
# Warning: Video file for ID 57641 does not exist.
# Warning: Video file for ID 57642 does not exist.
# Warning: Video file for ID 57643 does not exist.
# Warning: Video file for ID 62944 does not exist.
# Warning: Video file for ID 69531 does not exist.
# Warning: Video file for ID 68330 does not exist.
# Warning: Video file for ID 62967 does not exist.
# Warning: Video file for ID 62968 does not exist.
# Warning: Video file for ID 62982 does not exist.
# Warning: Video file for ID 62970 does not exist.
# Warning: Video file for ID 62984 does not exist.
# Warning: Video file for ID 62971 does not exist.
# Warning: Video file for ID 66769 does not exist.
# Warning: Video file for ID 67057 does not exist.
# Warning: Video file for ID 62986 does not exist.
# Warning: Video file for ID 62973 does not exist.
# Warning: Video file for ID 62987 does not exist.
# Warning: Video file for ID 62964 does not exist.
# Warning: Video file for ID 67058 does not exist.
# Warning: Video file for ID 62988 does not exist.
# Warning: Video file for ID 62975 does not exist.
# Warning: Video file for ID 62965 does not exist.
# Warning: Video file for ID 62979 does not exist.
# Warning: Video file for ID 62966 does not exist.
# Warning: Video file for ID 63662 does not exist.
# Warning: Video file for ID 68187 does not exist.
# Warning: Video file for ID 68764 does not exist.
# Warning: Video file for ID 63679 does not exist.
# Warning: Video file for ID 63665 does not exist.
# Warning: Video file for ID 63666 does not exist.
# Warning: Video file for ID 63667 does not exist.
# Warning: Video file for ID 63668 does not exist.
# Warning: Video file for ID 63669 does not exist.
# Warning: Video file for ID 63670 does not exist.
# Warning: Video file for ID 63671 does not exist.
# Warning: Video file for ID 63672 does not exist.
# Warning: Video file for ID 63673 does not exist.
# Warning: Video file for ID 66798 does not exist.
# Warning: Video file for ID 66799 does not exist.
# Warning: Video file for ID 63664 does not exist.
# Warning: Video file for ID 67078 does not exist.
# Warning: Video file for ID 63675 does not exist.
# Warning: Video file for ID 63676 does not exist.
# Warning: Video file for ID 63677 does not exist.
# Warning: Video file for ID 63678 does not exist.
# Warning: Video file for ID 05628 does not exist.
# Warning: Video file for ID 05643 does not exist.
# Warning: Video file for ID 05644 does not exist.
# Warning: Video file for ID 05629 does not exist.
# Warning: Video file for ID 05630 does not exist.
# Warning: Video file for ID 05631 does not exist.
# Warning: Video file for ID 05632 does not exist.
# Warning: Video file for ID 05633 does not exist.
# Warning: Video file for ID 05634 does not exist.
# Warning: Video file for ID 05635 does not exist.
# Warning: Video file for ID 05636 does not exist.
# Warning: Video file for ID 65162 does not exist.
# Warning: Video file for ID 05637 does not exist.
# Warning: Video file for ID 65163 does not exist.
# Warning: Video file for ID 65161 does not exist.
# Warning: Video file for ID 67400 does not exist.
# Warning: Video file for ID 05638 does not exist.
# Warning: Video file for ID 05639 does not exist.
# Warning: Video file for ID 05641 does not exist.
# Warning: Video file for ID 05642 does not exist.
# Warning: Video file for ID 06822 does not exist.
# Warning: Video file for ID 69238 does not exist.
# Warning: Video file for ID 68274 does not exist.
# Warning: Video file for ID 68010 does not exist.
# Warning: Video file for ID 06835 does not exist.
# Warning: Video file for ID 06836 does not exist.
# Warning: Video file for ID 06837 does not exist.
# Warning: Video file for ID 06838 does not exist.
# Warning: Video file for ID 06839 does not exist.
# Warning: Video file for ID 06840 does not exist.
# Warning: Video file for ID 06841 does not exist.
# Warning: Video file for ID 65216 does not exist.
# Warning: Video file for ID 06832 does not exist.
# Warning: Video file for ID 67420 does not exist.
# Warning: Video file for ID 06842 does not exist.
# Warning: Video file for ID 06843 does not exist.
# Warning: Video file for ID 06844 does not exist.
# Warning: Video file for ID 06845 does not exist.
# Warning: Video file for ID 06833 does not exist.
# Warning: Video file for ID 06834 does not exist.
# Warning: Video file for ID 07383 does not exist.
# Warning: Video file for ID 07403 does not exist.
# Warning: Video file for ID 07389 does not exist.
# Warning: Video file for ID 07390 does not exist.
# Warning: Video file for ID 07391 does not exist.
# Warning: Video file for ID 07392 does not exist.
# Warning: Video file for ID 07393 does not exist.
# Warning: Video file for ID 07394 does not exist.
# Warning: Video file for ID 07395 does not exist.
# Warning: Video file for ID 07396 does not exist.
# Warning: Video file for ID 07397 does not exist.
# Warning: Video file for ID 65242 does not exist.
# Warning: Video file for ID 65241 does not exist.
# Warning: Video file for ID 07388 does not exist.
# Warning: Video file for ID 67431 does not exist.
# Warning: Video file for ID 07398 does not exist.
# Warning: Video file for ID 07399 does not exist.
# Warning: Video file for ID 07400 does not exist.
# Warning: Video file for ID 07401 does not exist.
# Warning: Video file for ID 07402 does not exist.
# Warning: Video file for ID 69257 does not exist.
# Warning: Video file for ID 65294 does not exist.
# Warning: Video file for ID 08950 does not exist.
# Warning: Video file for ID 08951 does not exist.
# Warning: Video file for ID 08952 does not exist.
# Warning: Video file for ID 08953 does not exist.
# Warning: Video file for ID 08955 does not exist.
# Warning: Video file for ID 08935 does not exist.
# Warning: Video file for ID 08936 does not exist.
# Warning: Video file for ID 08937 does not exist.
# Warning: Video file for ID 08938 does not exist.
# Warning: Video file for ID 08939 does not exist.
# Warning: Video file for ID 08942 does not exist.
# Warning: Video file for ID 67465 does not exist.
# Warning: Video file for ID 08944 does not exist.
# Warning: Video file for ID 08945 does not exist.
# Warning: Video file for ID 08946 does not exist.
# Warning: Video file for ID 08947 does not exist.
# Warning: Video file for ID 08948 does not exist.
# Warning: Video file for ID 08949 does not exist.
# Warning: Video file for ID 17076 does not exist.
# Warning: Video file for ID 69298 does not exist.
# Warning: Video file for ID 68632 does not exist.
# Warning: Video file for ID 68035 does not exist.
# Warning: Video file for ID 17097 does not exist.
# Warning: Video file for ID 17084 does not exist.
# Warning: Video file for ID 17085 does not exist.
# Warning: Video file for ID 17086 does not exist.
# Warning: Video file for ID 17087 does not exist.
# Warning: Video file for ID 17088 does not exist.
# Warning: Video file for ID 17090 does not exist.
# Warning: Video file for ID 17091 does not exist.
# Warning: Video file for ID 17092 does not exist.
# Warning: Video file for ID 65506 does not exist.
# Warning: Video file for ID 65507 does not exist.
# Warning: Video file for ID 17083 does not exist.
# Warning: Video file for ID 67578 does not exist.
# Warning: Video file for ID 17093 does not exist.
# Warning: Video file for ID 17095 does not exist.
# Warning: Video file for ID 17096 does not exist.
# Warning: Video file for ID 20976 does not exist.
# Warning: Video file for ID 69316 does not exist.
# Warning: Video file for ID 69016 does not exist.
# Warning: Video file for ID 20980 does not exist.
# Warning: Video file for ID 20981 does not exist.
# Warning: Video file for ID 20982 does not exist.
# Warning: Video file for ID 20983 does not exist.
# Warning: Video file for ID 20984 does not exist.
# Warning: Video file for ID 20985 does not exist.
# Warning: Video file for ID 20986 does not exist.
# Warning: Video file for ID 20987 does not exist.
# Warning: Video file for ID 65677 does not exist.
# Warning: Video file for ID 20978 does not exist.
# Warning: Video file for ID 67642 does not exist.
# Warning: Video file for ID 20988 does not exist.
# Warning: Video file for ID 20989 does not exist.
# Warning: Video file for ID 20990 does not exist.
# Warning: Video file for ID 20991 does not exist.
# Warning: Video file for ID 20992 does not exist.
# Warning: Video file for ID 20979 does not exist.
# Warning: Video file for ID 22109 does not exist.
# Warning: Video file for ID 69325 does not exist.
# Warning: Video file for ID 22129 does not exist.
# Warning: Video file for ID 22130 does not exist.
# Warning: Video file for ID 22114 does not exist.
# Warning: Video file for ID 22115 does not exist.
# Warning: Video file for ID 22116 does not exist.
# Warning: Video file for ID 22117 does not exist.
# Warning: Video file for ID 22118 does not exist.
# Warning: Video file for ID 22119 does not exist.
# Warning: Video file for ID 22120 does not exist.
# Warning: Video file for ID 22121 does not exist.
# Warning: Video file for ID 65731 does not exist.
# Warning: Video file for ID 22113 does not exist.
# Warning: Video file for ID 67667 does not exist.
# Warning: Video file for ID 22124 does not exist.
# Warning: Video file for ID 22125 does not exist.
# Warning: Video file for ID 22126 does not exist.
# Warning: Video file for ID 22127 does not exist.
# Warning: Video file for ID 22128 does not exist.
# Warning: Video file for ID 25318 does not exist.
# Warning: Video file for ID 70176 does not exist.
# Warning: Video file for ID 68528 does not exist.
# Warning: Video file for ID 25337 does not exist.
# Warning: Video file for ID 25338 does not exist.
# Warning: Video file for ID 25339 does not exist.
# Warning: Video file for ID 25322 does not exist.
# Warning: Video file for ID 25323 does not exist.
# Warning: Video file for ID 25324 does not exist.
# Warning: Video file for ID 25325 does not exist.
# Warning: Video file for ID 25326 does not exist.
# Warning: Video file for ID 25327 does not exist.
# Warning: Video file for ID 25328 does not exist.
# Warning: Video file for ID 65843 does not exist.
# Warning: Video file for ID 25329 does not exist.
# Warning: Video file for ID 25330 does not exist.
# Warning: Video file for ID 25321 does not exist.
# Warning: Video file for ID 67722 does not exist.
# Warning: Video file for ID 25332 does not exist.
# Warning: Video file for ID 25333 does not exist.
# Warning: Video file for ID 26688 does not exist.
# Warning: Video file for ID 69359 does not exist.
# Warning: Video file for ID 68396 does not exist.
# Warning: Video file for ID 68068 does not exist.
# Warning: Video file for ID 26713 does not exist.
# Warning: Video file for ID 26736 does not exist.
# Warning: Video file for ID 26712 does not exist.
# Warning: Video file for ID 26739 does not exist.
# Warning: Video file for ID 26741 does not exist.
# Warning: Video file for ID 26714 does not exist.
# Warning: Video file for ID 26715 does not exist.
# Warning: Video file for ID 26716 does not exist.
# Warning: Video file for ID 26717 does not exist.
# Warning: Video file for ID 67745 does not exist.
# Warning: Video file for ID 26719 does not exist.
# Warning: Video file for ID 26721 does not exist.
# Warning: Video file for ID 26722 does not exist.
# Warning: Video file for ID 26723 does not exist.
# Warning: Video file for ID 26724 does not exist.
# Warning: Video file for ID 26726 does not exist.
# Warning: Video file for ID 65884 does not exist.
# Warning: Video file for ID 70016 does not exist.
# Warning: Video file for ID 68350 does not exist.
# Warning: Video file for ID 68070 does not exist.
# Warning: Video file for ID 26972 does not exist.
# Warning: Video file for ID 26973 does not exist.
# Warning: Video file for ID 26974 does not exist.
# Warning: Video file for ID 26975 does not exist.
# Warning: Video file for ID 26976 does not exist.
# Warning: Video file for ID 26977 does not exist.
# Warning: Video file for ID 26978 does not exist.
# Warning: Video file for ID 26971 does not exist.
# Warning: Video file for ID 26980 does not exist.
# Warning: Video file for ID 67750 does not exist.
# Warning: Video file for ID 26981 does not exist.
# Warning: Video file for ID 26982 does not exist.
# Warning: Video file for ID 26983 does not exist.
# Warning: Video file for ID 26984 does not exist.
# Warning: Video file for ID 26985 does not exist.
# Warning: Video file for ID 26986 does not exist.
# Warning: Video file for ID 31746 does not exist.
# Warning: Video file for ID 31765 does not exist.
# Warning: Video file for ID 31766 does not exist.
# Warning: Video file for ID 31767 does not exist.
# Warning: Video file for ID 31750 does not exist.
# Warning: Video file for ID 31751 does not exist.
# Warning: Video file for ID 31752 does not exist.
# Warning: Video file for ID 31753 does not exist.
# Warning: Video file for ID 31754 does not exist.
# Warning: Video file for ID 31755 does not exist.
# Warning: Video file for ID 31756 does not exist.
# Warning: Video file for ID 65996 does not exist.
# Warning: Video file for ID 31757 does not exist.
# Warning: Video file for ID 31758 does not exist.
# Warning: Video file for ID 31749 does not exist.
# Warning: Video file for ID 67817 does not exist.
# Warning: Video file for ID 31759 does not exist.
# Warning: Video file for ID 31762 does not exist.
# Warning: Video file for ID 31763 does not exist.
# Warning: Video file for ID 31764 does not exist.
# Warning: Video file for ID 32146 does not exist.
# Warning: Video file for ID 68084 does not exist.
# Warning: Video file for ID 68085 does not exist.
# Warning: Video file for ID 68904 does not exist.
# Warning: Video file for ID 32156 does not exist.
# Warning: Video file for ID 32157 does not exist.
# Warning: Video file for ID 32158 does not exist.
# Warning: Video file for ID 32160 does not exist.
# ...
# Warning: Video file for ID 55628 does not exist.
# Warning: Video file for ID 55630 does not exist.
# Warning: Video file for ID 55631 does not exist.
# Warning: Video file for ID 55632 does not exist.
# Warning: Video file for ID 55865 does not exist.
# Warning: Video file for ID 55866 does not exist.
# Warning: Video file for ID 55867 does not exist.
# Warning: Video file for ID 55868 does not exist.
# Warning: Video file for ID 55869 does not exist.
# Warning: Video file for ID 55870 does not exist.
# Warning: Video file for ID 55871 does not exist.
# Warning: Video file for ID 55910 does not exist.
# Warning: Video file for ID 55911 does not exist.
# Warning: Video file for ID 55913 does not exist.
# Warning: Video file for ID 55914 does not exist.
# Warning: Video file for ID 55915 does not exist.
# Warning: Video file for ID 55916 does not exist.
# Warning: Video file for ID 55917 does not exist.
# Warning: Video file for ID 56113 does not exist.
# Warning: Video file for ID 56114 does not exist.
# Warning: Video file for ID 56115 does not exist.
# Warning: Video file for ID 56116 does not exist.
# Warning: Video file for ID 56117 does not exist.
# Warning: Video file for ID 56118 does not exist.
# Warning: Video file for ID 56119 does not exist.
# Warning: Video file for ID 56168 does not exist.
# Warning: Video file for ID 56175 does not exist.
# Warning: Video file for ID 56176 does not exist.
# Warning: Video file for ID 56177 does not exist.
# Warning: Video file for ID 56178 does not exist.
# Warning: Video file for ID 56179 does not exist.
# Warning: Video file for ID 56180 does not exist.
# Warning: Video file for ID 56354 does not exist.
# Warning: Video file for ID 56355 does not exist.
# Warning: Video file for ID 56356 does not exist.
# Warning: Video file for ID 56357 does not exist.
# Warning: Video file for ID 56358 does not exist.
# Warning: Video file for ID 56359 does not exist.
# Warning: Video file for ID 56360 does not exist.
# Warning: Video file for ID 56546 does not exist.
# Warning: Video file for ID 66058 does not exist.
# Warning: Video file for ID 58323 does not exist.
# Warning: Video file for ID 58324 does not exist.
# Warning: Video file for ID 58325 does not exist.
# Warning: Video file for ID 58326 does not exist.
# Warning: Video file for ID 58327 does not exist.
# Warning: Video file for ID 56788 does not exist.
# Warning: Video file for ID 56792 does not exist.
# Warning: Video file for ID 56793 does not exist.
# Warning: Video file for ID 56794 does not exist.
# Warning: Video file for ID 56795 does not exist.
# Warning: Video file for ID 56797 does not exist.
# Warning: Video file for ID 56798 does not exist.
# Warning: Video file for ID 57251 does not exist.
# Warning: Video file for ID 57252 does not exist.
# Warning: Video file for ID 57253 does not exist.
# Warning: Video file for ID 57254 does not exist.
# Warning: Video file for ID 57255 does not exist.
# Warning: Video file for ID 57256 does not exist.
# Warning: Video file for ID 57257 does not exist.
# Warning: Video file for ID 57344 does not exist.
# Warning: Video file for ID 57349 does not exist.
# Warning: Video file for ID 57350 does not exist.
# Warning: Video file for ID 57351 does not exist.
# Warning: Video file for ID 57352 does not exist.
# Warning: Video file for ID 57353 does not exist.
# Warning: Video file for ID 57354 does not exist.
# Warning: Video file for ID 57391 does not exist.
# Warning: Video file for ID 57392 does not exist.
# Warning: Video file for ID 57393 does not exist.
# Warning: Video file for ID 57394 does not exist.
# Warning: Video file for ID 57395 does not exist.
# Warning: Video file for ID 57396 does not exist.
# Warning: Video file for ID 57397 does not exist.
# Warning: Video file for ID 57361 does not exist.
# Warning: Video file for ID 57378 does not exist.
# Warning: Video file for ID 57379 does not exist.
# Warning: Video file for ID 57380 does not exist.
# Warning: Video file for ID 57381 does not exist.
# Warning: Video file for ID 57382 does not exist.
# Warning: Video file for ID 57385 does not exist.
# Warning: Video file for ID 57542 does not exist.
# Warning: Video file for ID 57551 does not exist.
# Warning: Video file for ID 57552 does not exist.
# Warning: Video file for ID 57543 does not exist.
# Warning: Video file for ID 57545 does not exist.
# Warning: Video file for ID 57546 does not exist.
# Warning: Video file for ID 57548 does not exist.
# Warning: Video file for ID 57566 does not exist.
# Warning: Video file for ID 57567 does not exist.
# Warning: Video file for ID 57568 does not exist.
# Warning: Video file for ID 57569 does not exist.
# Warning: Video file for ID 57570 does not exist.
# Warning: Video file for ID 57571 does not exist.
# Warning: Video file for ID 57572 does not exist.
# Warning: Video file for ID 57584 does not exist.
# Warning: Video file for ID 66595 does not exist.
# Warning: Video file for ID 66596 does not exist.
# Warning: Video file for ID 67291 does not exist.
# Warning: Video file for ID 57579 does not exist.
# Warning: Video file for ID 57580 does not exist.
# Warning: Video file for ID 57582 does not exist.
# Warning: Video file for ID 57604 does not exist.
# Warning: Video file for ID 66597 does not exist.
# Warning: Video file for ID 57605 does not exist.
# Warning: Video file for ID 57606 does not exist.
# Warning: Video file for ID 57607 does not exist.
# Warning: Video file for ID 57609 does not exist.
# Warning: Video file for ID 57610 does not exist.
# Warning: Video file for ID 57818 does not exist.
# Warning: Video file for ID 57819 does not exist.
# Warning: Video file for ID 57820 does not exist.
# Warning: Video file for ID 57821 does not exist.
# Warning: Video file for ID 57822 does not exist.
# Warning: Video file for ID 57823 does not exist.
# Warning: Video file for ID 57824 does not exist.
# Warning: Video file for ID 58236 does not exist.
# Warning: Video file for ID 66634 does not exist.
# Warning: Video file for ID 58243 does not exist.
# Warning: Video file for ID 58244 does not exist.
# Warning: Video file for ID 58245 does not exist.
# Warning: Video file for ID 58246 does not exist.
# Warning: Video file for ID 58247 does not exist.
# Warning: Video file for ID 58663 does not exist.
# Warning: Video file for ID 67312 does not exist.
# Warning: Video file for ID 58664 does not exist.
# Warning: Video file for ID 58665 does not exist.
# Warning: Video file for ID 58666 does not exist.
# Warning: Video file for ID 58667 does not exist.
# Warning: Video file for ID 58669 does not exist.
# Warning: Video file for ID 58743 does not exist.
# Warning: Video file for ID 58745 does not exist.
# Warning: Video file for ID 58746 does not exist.
# Warning: Video file for ID 58747 does not exist.
# Warning: Video file for ID 58748 does not exist.
# Warning: Video file for ID 58749 does not exist.
# Warning: Video file for ID 58750 does not exist.
# Warning: Video file for ID 58768 does not exist.
# Warning: Video file for ID 58769 does not exist.
# Warning: Video file for ID 58770 does not exist.
# Warning: Video file for ID 58771 does not exist.
# Warning: Video file for ID 58772 does not exist.
# Warning: Video file for ID 58773 does not exist.
# Warning: Video file for ID 58774 does not exist.
# Warning: Video file for ID 59000 does not exist.
# Warning: Video file for ID 59001 does not exist.
# Warning: Video file for ID 59002 does not exist.
# Warning: Video file for ID 59003 does not exist.
# Warning: Video file for ID 59004 does not exist.
# Warning: Video file for ID 59005 does not exist.
# Warning: Video file for ID 59006 does not exist.
# Warning: Video file for ID 59120 does not exist.
# Warning: Video file for ID 59122 does not exist.
# Warning: Video file for ID 59123 does not exist.
# Warning: Video file for ID 59124 does not exist.
# Warning: Video file for ID 59125 does not exist.
# Warning: Video file for ID 59127 does not exist.
# Warning: Video file for ID 59129 does not exist.
# Warning: Video file for ID 59672 does not exist.
# Warning: Video file for ID 59673 does not exist.
# Warning: Video file for ID 59666 does not exist.
# Warning: Video file for ID 59668 does not exist.
# Warning: Video file for ID 59669 does not exist.
# Warning: Video file for ID 59670 does not exist.
# Warning: Video file for ID 59671 does not exist.
# Warning: Video file for ID 59839 does not exist.
# Warning: Video file for ID 59840 does not exist.
# Warning: Video file for ID 59841 does not exist.
# Warning: Video file for ID 59842 does not exist.
# Warning: Video file for ID 59843 does not exist.
# Warning: Video file for ID 59845 does not exist.
# Warning: Video file for ID 59846 does not exist.
# Warning: Video file for ID 59969 does not exist.
# Warning: Video file for ID 66684 does not exist.
# Warning: Video file for ID 59989 does not exist.
# Warning: Video file for ID 59991 does not exist.
# Warning: Video file for ID 59992 does not exist.
# Warning: Video file for ID 59993 does not exist.
# Warning: Video file for ID 59996 does not exist.
# Warning: Video file for ID 69520 does not exist.
# Warning: Video file for ID 68518 does not exist.
# Warning: Video file for ID 60072 does not exist.
# Warning: Video file for ID 67329 does not exist.
# Warning: Video file for ID 60073 does not exist.
# Warning: Video file for ID 60074 does not exist.
# Warning: Video file for ID 60075 does not exist.
# Warning: Video file for ID 60338 does not exist.
# Warning: Video file for ID 66059 does not exist.
# Warning: Video file for ID 60358 does not exist.
# Warning: Video file for ID 60359 does not exist.
# Warning: Video file for ID 60360 does not exist.
# Warning: Video file for ID 60361 does not exist.
# Warning: Video file for ID 60362 does not exist.
# Warning: Video file for ID 60701 does not exist.
# Warning: Video file for ID 60702 does not exist.
# Warning: Video file for ID 60703 does not exist.
# Warning: Video file for ID 60704 does not exist.
# Warning: Video file for ID 60705 does not exist.
# Warning: Video file for ID 60708 does not exist.
# Warning: Video file for ID 60709 does not exist.
# Warning: Video file for ID 60966 does not exist.
# Warning: Video file for ID 60967 does not exist.
# Warning: Video file for ID 60968 does not exist.
# Warning: Video file for ID 60969 does not exist.
# Warning: Video file for ID 60970 does not exist.
# Warning: Video file for ID 60972 does not exist.
# Warning: Video file for ID 60973 does not exist.
# Warning: Video file for ID 61130 does not exist.
# Warning: Video file for ID 66060 does not exist.
# Warning: Video file for ID 61561 does not exist.
# Warning: Video file for ID 61562 does not exist.
# Warning: Video file for ID 61563 does not exist.
# Warning: Video file for ID 61564 does not exist.
# Warning: Video file for ID 61565 does not exist.
# Warning: Video file for ID 61134 does not exist.
# Warning: Video file for ID 61135 does not exist.
# Warning: Video file for ID 61136 does not exist.
# Warning: Video file for ID 61137 does not exist.
# Warning: Video file for ID 61138 does not exist.
# Warning: Video file for ID 61139 does not exist.
# Warning: Video file for ID 61140 does not exist.
# Warning: Video file for ID 61187 does not exist.
# Warning: Video file for ID 61188 does not exist.
# Warning: Video file for ID 61189 does not exist.
# Warning: Video file for ID 61190 does not exist.
# Warning: Video file for ID 61191 does not exist.
# Warning: Video file for ID 61192 does not exist.
# Warning: Video file for ID 61193 does not exist.
# Warning: Video file for ID 61219 does not exist.
# Warning: Video file for ID 61221 does not exist.
# Warning: Video file for ID 61222 does not exist.
# Warning: Video file for ID 61223 does not exist.
# Warning: Video file for ID 61224 does not exist.
# Warning: Video file for ID 61225 does not exist.
# Warning: Video file for ID 61226 does not exist.
# Warning: Video file for ID 66718 does not exist.
# Warning: Video file for ID 61246 does not exist.
# Warning: Video file for ID 61247 does not exist.
# Warning: Video file for ID 61248 does not exist.
# Warning: Video file for ID 61249 does not exist.
# Warning: Video file for ID 61250 does not exist.
# Warning: Video file for ID 61251 does not exist.
# Warning: Video file for ID 69523 does not exist.
# Warning: Video file for ID 66722 does not exist.
# Warning: Video file for ID 61509 does not exist.
# Warning: Video file for ID 61510 does not exist.
# Warning: Video file for ID 61511 does not exist.
# Warning: Video file for ID 61512 does not exist.
# Warning: Video file for ID 61515 does not exist.
# Warning: Video file for ID 61587 does not exist.
# Warning: Video file for ID 61588 does not exist.
# Warning: Video file for ID 61590 does not exist.
# Warning: Video file for ID 61591 does not exist.
# Warning: Video file for ID 61592 does not exist.
# Warning: Video file for ID 61594 does not exist.
# Warning: Video file for ID 61595 does not exist.
# Warning: Video file for ID 61696 does not exist.
# Warning: Video file for ID 61697 does not exist.
# Warning: Video file for ID 61698 does not exist.
# Warning: Video file for ID 61699 does not exist.
# Warning: Video file for ID 61700 does not exist.
# Warning: Video file for ID 61701 does not exist.
# Warning: Video file for ID 61702 does not exist.
# Warning: Video file for ID 61845 does not exist.
# Warning: Video file for ID 66733 does not exist.
# Warning: Video file for ID 61846 does not exist.
# Warning: Video file for ID 61848 does not exist.
# Warning: Video file for ID 61849 does not exist.
# Warning: Video file for ID 61850 does not exist.
# Warning: Video file for ID 61851 does not exist.
# Warning: Video file for ID 66734 does not exist.
# Warning: Video file for ID 61869 does not exist.
# Warning: Video file for ID 61870 does not exist.
# Warning: Video file for ID 61871 does not exist.
# Warning: Video file for ID 61872 does not exist.
# Warning: Video file for ID 61874 does not exist.
# Warning: Video file for ID 61875 does not exist.
# Warning: Video file for ID 61946 does not exist.
# Warning: Video file for ID 61953 does not exist.
# Warning: Video file for ID 67030 does not exist.
# Warning: Video file for ID 61947 does not exist.
# Warning: Video file for ID 61948 does not exist.
# Warning: Video file for ID 61950 does not exist.
# Warning: Video file for ID 61952 does not exist.
# Warning: Video file for ID 62032 does not exist.
# Warning: Video file for ID 66061 does not exist.
# Warning: Video file for ID 63274 does not exist.
# Warning: Video file for ID 63275 does not exist.
# Warning: Video file for ID 63276 does not exist.
# Warning: Video file for ID 63277 does not exist.
# Warning: Video file for ID 63278 does not exist.
# Warning: Video file for ID 62384 does not exist.
# Warning: Video file for ID 70137 does not exist.
# Warning: Video file for ID 62393 does not exist.
# Warning: Video file for ID 62394 does not exist.
# Warning: Video file for ID 62395 does not exist.
# Warning: Video file for ID 62396 does not exist.
# Warning: Video file for ID 62398 does not exist.
# Warning: Video file for ID 62487 does not exist.
# Warning: Video file for ID 62488 does not exist.
# Warning: Video file for ID 62489 does not exist.
# Warning: Video file for ID 62490 does not exist.
# Warning: Video file for ID 62491 does not exist.
# Warning: Video file for ID 62492 does not exist.
# Warning: Video file for ID 62493 does not exist.
# Warning: Video file for ID 62781 does not exist.
# Warning: Video file for ID 70104 does not exist.
# Warning: Video file for ID 67053 does not exist.
# Warning: Video file for ID 62782 does not exist.
# Warning: Video file for ID 62783 does not exist.
# Warning: Video file for ID 62784 does not exist.
# Warning: Video file for ID 62785 does not exist.
# Warning: Video file for ID 63044 does not exist.
# Warning: Video file for ID 63045 does not exist.
# Warning: Video file for ID 63046 does not exist.
# Warning: Video file for ID 63047 does not exist.
# Warning: Video file for ID 63048 does not exist.
# Warning: Video file for ID 63049 does not exist.
# Warning: Video file for ID 63050 does not exist.
# Warning: Video file for ID 63185 does not exist.
# Warning: Video file for ID 67065 does not exist.
# Warning: Video file for ID 63186 does not exist.
# Warning: Video file for ID 63187 does not exist.
# Warning: Video file for ID 63188 does not exist.
# Warning: Video file for ID 63189 does not exist.
# Warning: Video file for ID 63190 does not exist.

# %%
example_valid_video_to_label = {video_id: label for video_id, label in video_to_label.items() if os.path.exists(os.path.join(videos_folder, f"{video_id}.mp4"))}

# Base directory to store extracted frames
base_output_dir = 'example_extracted_frames'

# Create directories for each gloss
for label in set(example_valid_video_to_label.values()):
    os.makedirs(os.path.join(base_output_dir, label), exist_ok=True)

# %%
# Function to extract frames from a video
def extract_frames(video_path, output_dir):
    cap = cv2.VideoCapture(video_path)
    frame_count = 0
    
    while True:
        ret, frame = cap.read()
        if not ret:
            break
            
        # Save frame
        frame_path = os.path.join(output_dir, f'frame_{frame_count:04d}.jpg')
        cv2.imwrite(frame_path, frame)
        frame_count += 1
        
    cap.release()

# Process each video
for video_id, label in example_valid_video_to_label.items():
    video_path = os.path.join(videos_folder, f"{video_id}.mp4")
    output_dir = os.path.join(base_output_dir, label, video_id)
    
    # Create directory for this specific video's frames
    os.makedirs(output_dir, exist_ok=True)
    
    print(f"Extracting frames from video {video_id} with label {label}")
    extract_frames(video_path, output_dir)

# %% [markdown]
# ## Loading The Dataset we created

# %%
from PIL import Image
import os
import torch
from torch.utils.data import Dataset
from torchvision import transforms
from sklearn.model_selection import train_test_split

class VideoDataset(Dataset):
    """
    This dataset expects that the videos are saved as folders of JPEG frames.
    
    The directory structure is assumed to be:
      root_dir/
          gloss_1/
              video_id_1/
                  frame001.jpg
                  frame002.jpg
                  ...
              video_id_2/
                  ...
          gloss_2/
              ...
    
    Args:
      root_dir (str): Path to the root directory.
      label2idx (dict): Mapping from gloss (str) to integer label.
      num_frames (int): Number of frames to sample per video.
      transform (callable, optional): Transformations to apply on the images.
      split (str, optional): "train" or "val". If provided splits the data (80% training, 20% validation).
    """
    def __init__(self, root_dir, label2idx, num_frames=16, transform=None, split=None):
        self.root_dir = root_dir
        self.label2idx = label2idx
        self.num_frames = num_frames
        self.transform = transform
        self.videos = []  # list of dictionaries: {'frames': list_of_frame_paths, 'label': int}
        
        # Walk through the directory structure and collect video data.
        for label in os.listdir(root_dir):
            label_path = os.path.join(root_dir, label)
            if os.path.isdir(label_path):
                for video in os.listdir(label_path):
                    video_path = os.path.join(label_path, video)
                    if os.path.isdir(video_path):
                        # Gather all JPEG frame paths and sort to maintain temporal order.
                        frame_files = sorted([
                            os.path.join(video_path, f)
                            for f in os.listdir(video_path)
                            if f.lower().endswith(('.jpeg', '.jpg'))
                        ])
                        # Skip videos with fewer frames than required.
                        if len(frame_files) < self.num_frames:
                            continue
                        self.videos.append({
                            'frames': frame_files,
                            'label': self.label2idx[label]
                        })
        
        # If split is specified, partition the videos list into train and validation sets.
        if split is not None:
            train_videos, val_videos = train_test_split(self.videos, test_size=0.2, random_state=42)
            if split == "train":
                self.videos = train_videos
            elif split == "val":
                self.videos = val_videos

    def __len__(self):
        return len(self.videos)

    def __getitem__(self, idx):
        video_info = self.videos[idx]
        frames = video_info['frames']
        
        # Uniformly sample exactly num_frames from the total available frames.
        total_frames = len(frames)
        interval = total_frames // self.num_frames
        selected_frames = [frames[i * interval] for i in range(self.num_frames)]
        
        video_tensor = []
        for frame_path in selected_frames:
            image = Image.open(frame_path).convert('RGB')
            if self.transform:
                image = self.transform(image)
            video_tensor.append(image)
        
        # Stack the frames to create a tensor of shape (num_frames, C, H, W)
        video_tensor = torch.stack(video_tensor)
        label = video_info['label']
        return video_tensor, label

# %%
import torch
import torch.nn as nn
import torchvision.models as models

class LRCN(nn.Module):
    """
    LRCN model that first extracts spatial features from each frame using a CNN
    (here, a pretrained ResNet18) and then models the temporal information with an LSTM.
    
    Args:
      num_classes (int): Number of output classes (unique glosses).
      hidden_size (int): Hidden layer size of the LSTM.
      num_layers (int): Number of LSTM layers.
      pretrained (bool): Whether to use pre-trained weights for the CNN.
    """
    def __init__(self, num_classes, hidden_size=256, num_layers=1, pretrained=True):
        super(LRCN, self).__init__()
        # Use ResNet18 as the CNN feature extractor
        resnet = models.resnet18(pretrained=pretrained)
        # Remove the final fully connected layer.
        modules = list(resnet.children())[:-1]  
        self.cnn = nn.Sequential(*modules)
        self.feature_size = resnet.fc.in_features  # typically 512 for resnet18
        
        # LSTM to process sequential features.
        self.lstm = nn.LSTM(input_size=self.feature_size, hidden_size=hidden_size,
                            num_layers=num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, num_classes)
    
    def forward(self, x):
        """
        Input:
          x: Tensor of shape (batch, seq_len, C, H, W)
        Output:
          out: Tensor of shape (batch, num_classes) with raw scores.
        """
        batch_size, seq_len, C, H, W = x.size()
        # Merge batch and sequence dimensions to process all frames through the CNN at once.
        x = x.view(batch_size * seq_len, C, H, W)
        features = self.cnn(x)  # shape becomes (batch * seq_len, feature_size, 1, 1)
        features = features.view(batch_size, seq_len, self.feature_size)
        
        # Pass the sequence of features through the LSTM.
        lstm_out, (hn, cn) = self.lstm(features)
        # Use the last output of the LSTM for classification.
        out = self.fc(lstm_out[:, -1, :])
        return out

# %%
import os
import torch
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms
from datasets.video_dataset import VideoDataset
from models.lrcn import LRCN

# -------------------------
# Hyperparameters & Settings
# -------------------------
data_root = 'example_extracted_frames'  # Root folder where frames are stored
num_frames = 16           # Number of frames to sample per video
batch_size = 8
num_epochs = 10
learning_rate = 1e-4
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# -------------------------
# Creating Label Mapping
# -------------------------
# Each folder in data_root represents a gloss. For repeatability, sort them.
labels = sorted([d for d in os.listdir(data_root) if os.path.isdir(os.path.join(data_root, d))])
label2idx = {label: idx for idx, label in enumerate(labels)}
num_classes = len(label2idx)
print("Label mapping:", label2idx)

# -------------------------
# Define Image Transforms
# -------------------------
# We resize images to 224x224 (common for ResNet) and normalize with ImageNet mean/std.
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], 
                         std=[0.229, 0.224, 0.225]),
])

if __name__ == '__main__':
    # -------------------------
    # Dataset and DataLoader
    # -------------------------
    dataset = VideoDataset(root_dir=data_root, label2idx=label2idx,
                           num_frames=num_frames, transform=transform)
    # For debugging on Windows, start by setting num_workers=0.
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=0)
    
    # -------------------------
    # Instantiate the Model, Loss, and Optimizer
    # -------------------------
    model = LRCN(num_classes=num_classes, hidden_size=256, num_layers=1, pretrained=True).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    
    # -------------------------
    # Training Loop
    # -------------------------
    model.train()
    for epoch in range(num_epochs):
        running_loss = 0.0
        correct = 0
        total = 0
        
        for videos, labels in dataloader:
            videos = videos.to(device)
            labels = labels.to(device)
    
            optimizer.zero_grad()
            outputs = model(videos)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    
            running_loss += loss.item() * videos.size(0)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        
        epoch_loss = running_loss / len(dataset)
        epoch_acc = correct / total
        print(f"Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.4f}")
    
    torch.save(model.state_dict(), "lrcn_model.pth")
# Out:
# Using device: cuda
# Label mapping: {'abdomen': 0, 'able': 1, 'about': 2}
# c:\Users\harsh\Desktop\Final Project\venv\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\harsh\Desktop\Final Project\venv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/10, Loss: 1.1054, Accuracy: 0.4545
# Epoch 2/10, Loss: 0.8563, Accuracy: 0.7273
# Epoch 3/10, Loss: 0.6317, Accuracy: 0.9091
# Epoch 4/10, Loss: 0.5184, Accuracy: 1.0000
# Epoch 5/10, Loss: 0.3957, Accuracy: 1.0000
# Epoch 6/10, Loss: 0.3179, Accuracy: 1.0000
# Epoch 7/10, Loss: 0.3017, Accuracy: 0.9091
# Epoch 8/10, Loss: 0.3163, Accuracy: 0.9091
# Epoch 9/10, Loss: 0.1726, Accuracy: 1.0000
# Epoch 10/10, Loss: 0.2504, Accuracy: 0.9091

# %%
import os
import torch
from torch.utils.data import DataLoader
import torch.nn as nn
from torchvision import transforms
from datasets.video_dataset import VideoDataset
from models.lrcn import LRCN
from sklearn.metrics import confusion_matrix, classification_report

# -------------------------
# Settings and Hyperparameters
# -------------------------
data_root = 'example_extracted_frames'  # No train/val split in this example; you may want to create one.
num_frames = 16
batch_size = 8
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# -------------------------
# Label Mapping
# -------------------------
# Each folder in data_root represents a unique gloss/label.
labels = sorted([d for d in os.listdir(data_root) if os.path.isdir(os.path.join(data_root, d))])
label2idx = {label: idx for idx, label in enumerate(labels)}
# For reporting, create a reverse mapping: integer -> label name.
idx2label = {idx: label for label, idx in label2idx.items()}
num_classes = len(label2idx)
print("Label mapping:", label2idx)

# -------------------------
# Define Transforms (same as training)
# -------------------------
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Helps match input size for ResNet
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], 
                         std=[0.229, 0.224, 0.225]),
])

# -------------------------
# Create the Dataset and DataLoader for Evaluation
# -------------------------
dataset = VideoDataset(root_dir=data_root, label2idx=label2idx,
                       num_frames=num_frames, transform=transform)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False, num_workers=0)

# -------------------------
# Load the Trained Model
# -------------------------
model = LRCN(num_classes=num_classes, hidden_size=256, num_layers=1, pretrained=True).to(device)
model.load_state_dict(torch.load("lrcn_model.pth", map_location=device))
model.eval()  # IMPORTANT: Set the model to evaluation mode

criterion = nn.CrossEntropyLoss()

# -------------------------
# Evaluation Function
# -------------------------
def evaluate(model, dataloader, criterion, device):
    model.eval()
    total_loss = 0.0
    total_correct = 0
    total_samples = 0
    all_preds = []
    all_labels = []
    
    with torch.no_grad():
        for videos, labels in dataloader:
            videos = videos.to(device)
            labels = labels.to(device)
            
            outputs = model(videos)
            loss = criterion(outputs, labels)
            total_loss += loss.item() * videos.size(0)
            
            _, preds = torch.max(outputs, 1)
            total_correct += (preds == labels).sum().item()
            total_samples += labels.size(0)
            
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    
    avg_loss = total_loss / total_samples
    accuracy = total_correct / total_samples
    return avg_loss, accuracy, all_preds, all_labels

# -------------------------
# Run Evaluation
# -------------------------
avg_loss, accuracy, all_preds, all_labels = evaluate(model, dataloader, criterion, device)
print(f"Evaluation Loss: {avg_loss:.4f}")
print(f"Evaluation Accuracy: {accuracy:.4f}")

# -------------------------
# Further Analysis with Confusion Matrix & Classification Report
# -------------------------
cm = confusion_matrix(all_labels, all_preds)
print("Confusion Matrix:")
print(cm)

report = classification_report(all_labels, all_preds, target_names=labels)
print("Classification Report:")
print(report)
# Out:
# Label mapping: {'abdomen': 0, 'able': 1, 'about': 2}
# C:\Users\harsh\AppData\Local\Temp\ipykernel_52028\3984345.py:50: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("lrcn_model.pth", map_location=device))
# Evaluation Loss: 0.0845
# Evaluation Accuracy: 1.0000
# Confusion Matrix:
# [[5 0 0]
#  [0 5 0]
#  [0 0 1]]
# Classification Report:
#               precision    recall  f1-score   support
#
#      abdomen       1.00      1.00      1.00         5
#         able       1.00      1.00      1.00         5
#        about       1.00      1.00      1.00         1
#
#     accuracy                           1.00        11
#    macro avg       1.00      1.00      1.00        11
# weighted avg       1.00      1.00      1.00        11
